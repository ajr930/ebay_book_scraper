# %%
import pandas as pd
import numpy as np
from selenium import webdriver
from bs4 import BeautifulSoup as bs

# %%
import chromedriver_binary

# %%
driver = webdriver.Chrome()
url = 'https://www.bookfinder.com/buyback/search/#9781454881797'
driver.get(url)

# %%
url = 'https://www.bookfinder.com/buyback/search/#9781454881797'
driver.get(url)

# %%
isbn_numbers =

# %%
ls
# Out:
# Bookfinder automation.ipynb    chromedriver_mac64_m1 (1).zip
# Untitled.ipynb                 ebay_book_scrape.ipynb
# chromedriver*                  ebay_scrape

# %%
df =pd.read_csv('ebay_scrape2.csv')

# %%
df
# Out:
#      Unnamed: 0                               isbn_numbers price_list  \
# 0             0         MPN:Does not apply ISBN:0134555635     $53.39
# 1             1   Artist:Kakutani, Michiko ISBN:0525574972     $10.30
# 2             2         Personalized:No ISBN:9780997693768     $25.50
# 3             3   ISBN:9781629973296 Publication Year:2016     $24.00
# 4             4       Subject:Barbering ISBN:9781305100558     $75.00
# ..          ...                                        ...        ...
# 545         545        Type:Style Guide ISBN:9780958057141     $32.99
# 546         546   ISBN:9780735216204 Publication Year:2017     $12.99
# 547         547       ISBN:9780981626727 EAN:9780981626727     $45.00
# 548         548       ISBN:9780134464459 EAN:9780134464459     $47.88
# 549         549      Subject:Literature ISBN:9781554811038     $15.99
#
#                                              book_urls                isbn
# 0    https://www.ebay.com/itm/254545057420?epid=235...                 NaN
# 1    https://www.ebay.com/itm/274912524965?epid=210...                 NaN
# 2    https://www.ebay.com/itm/165294488549?epid=236... 9780997693768.00000
# 3    https://www.ebay.com/itm/234389961066?epid=803... 9781629973296.00000
# 4    https://www.ebay.com/itm/353871160614?epid=219... 9781305100558.00000
# ..                                                 ...                 ...
# 545  https://www.ebay.com/itm/153694545783?epid=802... 9780958057141.00000
# 546  https://www.ebay.com/itm/313845736316?epid=236... 9780735216204.00000
# 547  https://www.ebay.com/itm/393850008655?epid=126... 9780981626727.00000
# 548  https://www.ebay.com/itm/115213495051?epid=228... 9780134464459.00000
# 549  https://www.ebay.com/itm/175123080812?epid=117... 9781554811038.00000
#
# [550 rows x 5 columns]

# %%
df= df.dropna()

# %%
df['isbn']=df['isbn'].astype(int)
# Out:
# <ipython-input-84-33dd74101249>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['isbn']=df['isbn'].astype(int)

# %%
df
# Out:
#      Unnamed: 0                               isbn_numbers price_list  \
# 2             2         Personalized:No ISBN:9780997693768     $25.50
# 3             3   ISBN:9781629973296 Publication Year:2016     $24.00
# 4             4       Subject:Barbering ISBN:9781305100558     $75.00
# 5             5                         ISBN:9780133970777     $20.94
# 6             6   ISBN:9781629972725 Publication Year:2016     $15.90
# ..          ...                                        ...        ...
# 545         545        Type:Style Guide ISBN:9780958057141     $32.99
# 546         546   ISBN:9780735216204 Publication Year:2017     $12.99
# 547         547       ISBN:9780981626727 EAN:9780981626727     $45.00
# 548         548       ISBN:9780134464459 EAN:9780134464459     $47.88
# 549         549      Subject:Literature ISBN:9781554811038     $15.99
#
#                                              book_urls           isbn
# 2    https://www.ebay.com/itm/165294488549?epid=236...  9780997693768
# 3    https://www.ebay.com/itm/234389961066?epid=803...  9781629973296
# 4    https://www.ebay.com/itm/353871160614?epid=219...  9781305100558
# 5    https://www.ebay.com/itm/333179777085?epid=210...  9780133970777
# 6    https://www.ebay.com/itm/393889694561?epid=110...  9781629972725
# ..                                                 ...            ...
# 545  https://www.ebay.com/itm/153694545783?epid=802...  9780958057141
# 546  https://www.ebay.com/itm/313845736316?epid=236...  9780735216204
# 547  https://www.ebay.com/itm/393850008655?epid=126...  9780981626727
# 548  https://www.ebay.com/itm/115213495051?epid=228...  9780134464459
# 549  https://www.ebay.com/itm/175123080812?epid=117...  9781554811038
#
# [470 rows x 5 columns]

# %%
df['isbn']=df['isbn'].astype(str)
# Out:
# <ipython-input-86-ec4b6613c718>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['isbn']=df['isbn'].astype(str)

# %%
df
# Out:
#      Unnamed: 0                               isbn_numbers price_list  \
# 2             2         Personalized:No ISBN:9780997693768     $25.50
# 3             3   ISBN:9781629973296 Publication Year:2016     $24.00
# 4             4       Subject:Barbering ISBN:9781305100558     $75.00
# 5             5                         ISBN:9780133970777     $20.94
# 6             6   ISBN:9781629972725 Publication Year:2016     $15.90
# ..          ...                                        ...        ...
# 545         545        Type:Style Guide ISBN:9780958057141     $32.99
# 546         546   ISBN:9780735216204 Publication Year:2017     $12.99
# 547         547       ISBN:9780981626727 EAN:9780981626727     $45.00
# 548         548       ISBN:9780134464459 EAN:9780134464459     $47.88
# 549         549      Subject:Literature ISBN:9781554811038     $15.99
#
#                                              book_urls           isbn
# 2    https://www.ebay.com/itm/165294488549?epid=236...  9780997693768
# 3    https://www.ebay.com/itm/234389961066?epid=803...  9781629973296
# 4    https://www.ebay.com/itm/353871160614?epid=219...  9781305100558
# 5    https://www.ebay.com/itm/333179777085?epid=210...  9780133970777
# 6    https://www.ebay.com/itm/393889694561?epid=110...  9781629972725
# ..                                                 ...            ...
# 545  https://www.ebay.com/itm/153694545783?epid=802...  9780958057141
# 546  https://www.ebay.com/itm/313845736316?epid=236...  9780735216204
# 547  https://www.ebay.com/itm/393850008655?epid=126...  9780981626727
# 548  https://www.ebay.com/itm/115213495051?epid=228...  9780134464459
# 549  https://www.ebay.com/itm/175123080812?epid=117...  9781554811038
#
# [470 rows x 5 columns]

# %%
df['isbn']=df['isbn'].apply(lambda x: f"{x+' '}")
# Out:
# <ipython-input-88-2379fbbe7731>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['isbn']=df['isbn'].apply(lambda x: f"{x+' '}")

# %%
df
# Out:
#      Unnamed: 0                               isbn_numbers price_list  \
# 2             2         Personalized:No ISBN:9780997693768     $25.50
# 3             3   ISBN:9781629973296 Publication Year:2016     $24.00
# 4             4       Subject:Barbering ISBN:9781305100558     $75.00
# 5             5                         ISBN:9780133970777     $20.94
# 6             6   ISBN:9781629972725 Publication Year:2016     $15.90
# ..          ...                                        ...        ...
# 545         545        Type:Style Guide ISBN:9780958057141     $32.99
# 546         546   ISBN:9780735216204 Publication Year:2017     $12.99
# 547         547       ISBN:9780981626727 EAN:9780981626727     $45.00
# 548         548       ISBN:9780134464459 EAN:9780134464459     $47.88
# 549         549      Subject:Literature ISBN:9781554811038     $15.99
#
#                                              book_urls            isbn
# 2    https://www.ebay.com/itm/165294488549?epid=236...  9780997693768
# 3    https://www.ebay.com/itm/234389961066?epid=803...  9781629973296
# 4    https://www.ebay.com/itm/353871160614?epid=219...  9781305100558
# 5    https://www.ebay.com/itm/333179777085?epid=210...  9780133970777
# 6    https://www.ebay.com/itm/393889694561?epid=110...  9781629972725
# ..                                                 ...             ...
# 545  https://www.ebay.com/itm/153694545783?epid=802...  9780958057141
# 546  https://www.ebay.com/itm/313845736316?epid=236...  9780735216204
# 547  https://www.ebay.com/itm/393850008655?epid=126...  9780981626727
# 548  https://www.ebay.com/itm/115213495051?epid=228...  9780134464459
# 549  https://www.ebay.com/itm/175123080812?epid=117...  9781554811038
#
# [470 rows x 5 columns]

# %%
isbn_list = []
for i in df['isbn']:
    isbn_list.append(i)

# %%
len(isbn_list)
# Out:
# 470

# %%
driver = webdriver.Chrome()
url = 'https://www.bookfinder.com/buyback/search/#9781454881797'
driver.get(url)

# %%
isbn_fill_form = driver.find_element_by_xpath('//*[@id="isbn"]')

# %%
isbn_fill_form.send_keys(isbn_list)

# %%
for isbn in isbn_list:
    isbn_fill_form.send_keys(isbn)
